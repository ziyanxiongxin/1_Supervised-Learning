# %%
import pandas as pd
from collections import Counter
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import KFold,cross_validate
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from imblearn.under_sampling import RandomUnderSampler
from imblearn.pipeline import Pipeline
# from category_encoders import *
import numpy as np
# from sklearn.metrics import accuracy_score
from sklearn.metrics import average_precision_score,recall_score
import time
import matplotlib.pyplot as plt
# import seaborn as sns
import io
# from google.colab import files


# uploaded = files.upload()
# #extract the data
# raw_df = pd.read_csv(io.BytesIO(uploaded['BitcoinHeistData.csv']))


# #extract the data
raw_df = pd.read_csv('BitcoinHeistData.csv')
cleaned_df = raw_df.copy()
cleaned_df['class']=np.array([0 if x=='white' else 1 for x in cleaned_df.pop('label')])

cleaned_df.pop("address")
cleaned_df.pop("year")
cleaned_df.pop("day")

# cleaned_df.pop("looped")
eps=0.001 # 0 => 0.1¢
cleaned_df['Log income'] = np.log(cleaned_df.pop('income')+eps)
cleaned_df['Log weight'] = np.log(cleaned_df.pop('weight')+eps)
print(cleaned_df.head(5))

#summarize the data distribution
y=np.array(cleaned_df['class'])
X=np.array(cleaned_df.iloc[:,:-1])
print(Counter(y))

#rescale data
scaler = StandardScaler()
X = scaler.fit_transform(X)


#define the undersampling method
under = RandomUnderSampler(sampling_strategy=0.5)
k=7
cv = KFold(n_splits=k,shuffle=True)


##cross validation to find out the best hidden_layer_size using kd_tree###
recall_train_score_list=[]
recall_test_score_list=[]
AP_train_score_list=[]
AP_test_score_list=[]
fit_time_list=[]

hidden_layer_sizes = [(i,j,k) for i in range(5,8) for j in range(5,8) for k in range(5,8)]
activation = ['logistic','tanh']
# parameters=(n_neighbors=5, *, weights='uniform', algorithm='auto', leaf_size=30, p=2, metric='minkowski', metric_params=None, n_jobs=None, **kwargs)[source]
for hidden_layer_size in hidden_layer_sizes:
    MLP = MLPClassifier(hidden_layer_sizes=hidden_layer_size,activation ='tanh',solver='sgd',max_iter=500,batch_size=3000)
    steps = [('under',under),('model',MLP)]
    pipeline = Pipeline(steps=steps)
    scores =  cross_validate(pipeline, X, y, scoring=['recall','average_precision'], cv=cv, n_jobs=-1,return_train_score=True)
    recall_train_score_list.append(sum(scores['train_recall'])/k)
    recall_test_score_list.append(sum(scores['test_recall'])/k)
    
    AP_train_score_list.append(sum(scores['train_average_precision'])/k)
    AP_test_score_list.append(sum(scores['test_average_precision'])/k)
    fit_time_list.append(sum(scores['fit_time'])/k)
    
m = len(hidden_layer_sizes)
hidden_layer_sizes_text=[str(hidden_layer_size[0])+str(hidden_layer_size[1])+str(hidden_layer_size[2]) for hidden_layer_size in hidden_layer_sizes]
print(hidden_layer_sizes_text)
# #generate Fig_0,Fig_1
fig_0, axs = plt.subplots(1, 1, figsize=(5, 5), sharey=True)
axs.plot(hidden_layer_sizes_text[:m],fit_time_list[:m],label="fit_time,seconds")
axs.set_xlabel("neighbors_num with kd_tree")
axs.set_ylabel("fit_time")
axs.legend()
fig_0.suptitle("Fig_1.2.0: Fit_time")

fig_0.savefig("NN_fig_1.2_tanh:Fit_time.png")



fig_1, axs = plt.subplots(1, 2, figsize=(10, 5), sharey=True)
axs[0].plot(hidden_layer_sizes_text[:m],recall_train_score_list[:m],"r^",linestyle = "--",label='training data')
axs[0].plot(hidden_layer_sizes_text[:m],recall_test_score_list[:m],"b^",linestyle = "--",label='test data')
axs[0].set_xlabel('hidden_layer_sizes')
axs[0].set_ylabel('Recall_score')
axs[1].plot(hidden_layer_sizes_text[:m],AP_train_score_list[:m],"r^",linestyle = "--",label='training data')
axs[1].plot(hidden_layer_sizes_text[:m],AP_test_score_list[:m],"b^",linestyle = "--",label='test data')
axs[1].set_xlabel('neighbors_num with kd_tree')
axs[1].set_ylabel('AP_score')
fig_1.suptitle('Fig_1.2.1:Recall_score,AP_score')

axs[0].legend()
axs[1].legend()
fig_1.savefig("NN_fig_1.2_tanh:scores.png")
# Out:
#    length  count  looped  neighbors  class  Log income  Log weight
# 0      18      1       0          2      1   18.421181   -4.674163
# 1      44      1       0          1      1   18.420681   -6.689310
# 2       0      1       0          2      1   19.113828    0.001000
# 3      72      1       0          2      1   18.081003   -5.317245
# 4     144    456       0          1      1   19.113828   -2.605741
# Counter({0: 2875284, 1: 41413})
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/.local/lib/python3.7/site-packages/matplotlib/axes/_axes.py in _convert_dx(dx, x0, xconv, convert)
#    2154                 delist = True
# -> 2155             dx = [convert(x0 + ddx) - x for ddx in dx]
#    2156             if delist:
#
# ~/.local/lib/python3.7/site-packages/matplotlib/axes/_axes.py in <listcomp>(.0)
#    2154                 delist = True
# ...

# %%
m = len(hidden_layer_sizes)
hidden_layer_sizes_text=[str(hidden_layer_size[0])+str(hidden_layer_size[1])+str(hidden_layer_size[2]) for hidden_layer_size in hidden_layer_sizes]
# print(hidden_layer_sizes_text[:9])
# #generate Fig_0,Fig_1
fig_0, axs = plt.subplots(1, 1, figsize=(5, 5), sharey=True)
axs.plot(hidden_layer_sizes_text[:m],fit_time_list[:m],label="fit_time,seconds")
axs.set_xlabel("hidden_layer_size")
axs.set_ylabel("fit_time")
axs.legend()
fig_0.suptitle("Fig_1.2.0: Fit_time (activation=tanh)")

fig_0.savefig("NN_fig_1.2_tanh:Fit_time.png")



fig_1, axs = plt.subplots(1, 2, figsize=(10, 5), sharey=True)
axs[0].plot(hidden_layer_sizes_text[:m],recall_train_score_list[:m],"r^",linestyle = "--",label='training data')
axs[0].plot(hidden_layer_sizes_text[:m],recall_test_score_list[:m],"b^",linestyle = "--",label='test data')
axs[0].set_xlabel('hidden_layer_sizes')
axs[0].set_ylabel('Recall_score')
axs[1].plot(hidden_layer_sizes_text[:m],AP_train_score_list[:m],"r^",linestyle = "--",label='training data')
axs[1].plot(hidden_layer_sizes_text[:m],AP_test_score_list[:m],"b^",linestyle = "--",label='test data')
axs[1].set_xlabel('hidden_layer_size')
axs[1].set_ylabel('AP_score')
fig_1.suptitle('Fig_1.2.1:Recall_score,AP_score(activation=tanh)')

axs[0].legend()
axs[1].legend()
fig_1.savefig("NN_fig_1.2_tanh:scores.png")

# %%
print(type(hidden_layer_sizes_text))
print(len(fit_time_list))
# Out:
# <class 'list'>
# 27

# %%
print(cleaned_df.head(5))

# %%
print(cleaned_df['weight'])

# %%
dataset[['address','label']].describe()

# %%
from sklearn.preprocessing import StandardScaler
data = [[0, 0], [0, 0], [1, 1], [1, 1]]
scaler = StandardScaler()
print(scaler.fit(data))
StandardScaler()
print(scaler.mean_)
print(scaler.var_)
print(scaler.transform(data))
print(scaler.transform([[2, 2]]))

# %%
print(X_train[bool_train_labels])

# %%
print(X_train[~bool_train_labels])

# %%
df = cleaned_df.head(5)
print(df)

# %%
df = cleaned_df.head(5)
train_label = np.array(df.pop('class')-1)
bool_train_label = train_label !=0
train_features = np.array(df)
print(train_features)
df = cleaned_df.head(5)
print(bool_train_label)
print(train_features[bool_train_label])

# %%
acc_train_score = accuracy_score(y_train,y_train_predict) 
acc_test_score = accuracy_score(y_test,y_test_predict)
acc_val_score = accuracy_score(y_val,y_val_predict)
recall_train_score = recall_score(y_train,y_train_predict,average='binary')
recall_test_score = recall_score(y_test,y_test_predict,average='binary')
recall_val_score = recall_score(y_val,y_val_predict,average='binary')
y_train_predict_pos_prob = clf.predict_proba(X_train)[:,1]
y_test_predict_pos_prob = clf.predict_proba(X_test)[:,1]
y_val_predict_pos_prob = clf.predict_proba(X_val)[:,1]
AP_train_score = average_precision_score(y_train,y_train_predict_pos_prob)
AP_test_score = average_precision_score(y_test,y_test_predict_pos_prob)
AP_val_score = average_precision_score(y_val,y_val_predict_pos_prob)
print("probability on test data:",clf.predict_proba(X_test))
print("probability on training data:",clf.predict_proba(X_train))
print("scores for test data:", acc_test_score,recall_test_score,AP_test_score)
print("scores for training data:", acc_train_score,recall_train_score,AP_train_score)
print("scores for validation data:", acc_val_score,recall_val_score,AP_val_score)
